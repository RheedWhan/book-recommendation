# %%
# Import necessary libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Import the dataset
df_raw = pd.read_csv(r'C:\Users\Ojo Ridwan\Desktop\Amazon book rec\kindle_data-v2.csv')
df_raw.head(2) # The first 2 rows
# Out:
#          asin                                              title  \
# 0  B00TZE87S4  Adult Children of Emotionally Immature Parents...
# 1  B08WCKY8MB  From Strength to Strength: Finding Success, Ha...
#
#               author                   soldBy  \
# 0  Lindsay C. Gibson  Amazon.com Services LLC
# 1   Arthur C. Brooks  Penguin Group (USA) LLC
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/713KZTsaYp...
# 1  https://m.media-amazon.com/images/I/A1LZcJFs9E...
#
#                              productURL  stars  reviews  price  \
# 0  https://www.amazon.com/dp/B00TZE87S4    4.8        0   9.99
# 1  https://www.amazon.com/dp/B08WCKY8MB    4.4        0  16.99
#
#    isKindleUnlimited  category_id  isBestSeller  isEditorsPick  \
# 0              False            6          True          False
# 1              False            6         False          False
#
#    isGoodReadsChoice publishedDate              category_name
# 0              False    2015-06-01  Parenting & Relationships
# 1              False    2022-02-15  Parenting & Relationships

# %%
df_raw.shape # Number of columns and rows in the dataset
# Out:
# (133102, 16)

# %%
df_raw.info() # Information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133102 entries, 0 to 133101
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   asin               133102 non-null  object
#  1   title              133102 non-null  object
#  2   author             132677 non-null  object
#  3   soldBy             123869 non-null  object
#  4   imgUrl             133102 non-null  object
#  5   productURL         133102 non-null  object
#  6   stars              133102 non-null  float64
#  7   reviews            133102 non-null  int64
#  8   price              133102 non-null  float64
#  9   isKindleUnlimited  133102 non-null  bool
#  10  category_id        133102 non-null  int64
#  11  isBestSeller       133102 non-null  bool
#  12  isEditorsPick      133102 non-null  bool
#  13  isGoodReadsChoice  133102 non-null  bool
#  14  publishedDate      84086 non-null   object
#  15  category_name      133102 non-null  object
# dtypes: bool(4), float64(2), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
df_raw.isna().sum() # Check missing values
# Out:
# asin                     0
# title                    0
# author                 425
# soldBy                9233
# imgUrl                   0
# productURL               0
# stars                    0
# reviews                  0
# price                    0
# isKindleUnlimited        0
# category_id              0
# isBestSeller             0
# isEditorsPick            0
# isGoodReadsChoice        0
# publishedDate        49016
# category_name            0
# dtype: int64

# %%
# Drop columns not needed
df = df_raw.copy() # copy dataset before dropping

columns_to_drop = ['asin', 'isKindleUnlimited', 'publishedDate', 'category_id']
df = df.drop(columns=columns_to_drop, axis=1)

# %%
df.columns
# Out:
# Index(['title', 'author', 'soldBy', 'imgUrl', 'productURL', 'stars', 'reviews',
#        'price', 'isBestSeller', 'isEditorsPick', 'isGoodReadsChoice',
#        'category_name'],
#       dtype='object')

# %%
df.isna().sum() # we still have some missing data to deal with
# Out:
# title                   0
# author                425
# soldBy               9233
# imgUrl                  0
# productURL              0
# stars                   0
# reviews                 0
# price                   0
# isBestSeller            0
# isEditorsPick           0
# isGoodReadsChoice       0
# category_name           0
# dtype: int64

# %%
# Drop missing data
df.dropna(inplace=True)

# %% [markdown]
# ### Exploratory Analysis

# %%
def top(dataframe, column, num):
    """
    Returns the top N items based on the specified column in a DataFrame.

    Parameters:
    - dataframe: pandas DataFrame
    - column: str, the column to sort by
    - num: int, the number of top items to return

    Returns:
    - pandas DataFrame containing the top N items
    """
    top_items = dataframe.sort_values(by=column, ascending=False).head(num)
    return top_items

# %%
# top 5 prices
top_5_prices = top(df, 'price', 5)
top_5_prices
# Out:
#                                                     title  \
# 123336  Drugs in Litigation: Damage Awards Involving P...
# 125981                           Broker-Dealer Regulation
# 15712   Youmans and Winn Neurological Surgery E-Book: ...
# 123725                  How to Write a Patent Application
# 113257  The Collected Works of C. G. Jung: Revised and...
#
#                             author                   soldBy  \
# 123336  LexisNexis Editorial Staff  Amazon.com Services LLC
# 125981          Clifford E. Kirsch  Amazon.com Services LLC
# 15712              H. Richard Winn  Amazon.com Services LLC
# 123725          Jeffrey G. Sheldon  Amazon.com Services LLC
# 113257                  C. G. Jung  Amazon.com Services LLC
#
#                                                    imgUrl  \
# 123336  https://m.media-amazon.com/images/I/419+UKcVsz...
# 125981  https://m.media-amazon.com/images/I/717G-NmJz5...
# 15712   https://m.media-amazon.com/images/I/81DPrUgIcc...
# 123725  https://m.media-amazon.com/images/I/71CQ6HRR39...
# 113257  https://m.media-amazon.com/images/I/61Ao84Fx3i...
#
#                                   productURL  stars  reviews   price  \
# 123336  https://www.amazon.com/dp/B0CFWJB1PX    0.0        0  682.00
# 125981  https://www.amazon.com/dp/B006NYK31S    0.0        0  662.00
# 15712   https://www.amazon.com/dp/B09S3H9KWB    4.1        0  636.99
# 123725  https://www.amazon.com/dp/B017HM6F1Q    3.5        0  629.00
# 113257  https://www.amazon.com/dp/B0C15XY3C1    0.0        0  549.99
#
#         isBestSeller  isEditorsPick  isGoodReadsChoice  \
# 123336         False          False              False
# 125981         False          False              False
# 15712          False          False              False
# 123725         False          False              False
# 113257         False          False              False
#
#                     category_name
# 123336                        Law
# 125981                        Law
# 15712              Science & Math
# 123725                        Law
# 113257  Health, Fitness & Dieting

# %%
# top 5 rewiews
top_5_reviews = top(df, 'reviews', 5)
top_5_reviews
# Out:
#                                title          author  \
# 28874        Where the Crawdads Sing     Delia Owens
# 28628       It Ends with Us: A Novel  Colleen Hoover
# 28641       The Nightingale: A Novel  Kristin Hannah
# 28634      Reminders of Him: A Novel  Colleen Hoover
# 28654  The Midnight Library: A Novel       Matt Haig
#
#                                      soldBy  \
# 28874               Penguin Group (USA) LLC
# 28628  Simon and Schuster Digital Sales Inc
# 28641                             Macmillan
# 28634               Amazon.com Services LLC
# 28654               Penguin Group (USA) LLC
#
#                                                   imgUrl  \
# 28874  https://m.media-amazon.com/images/I/91nCsvKqE5...
# 28628  https://m.media-amazon.com/images/I/81s0B6NYXM...
# 28641  https://m.media-amazon.com/images/I/81OkWjcf4W...
# 28634  https://m.media-amazon.com/images/I/71rdsaOMvV...
# 28654  https://m.media-amazon.com/images/I/81JBtGoYyO...
#
#                                  productURL  stars  reviews  price  \
# 28874  https://www.amazon.com/dp/B078GD3DRG    4.7   618227  12.99
# 28628  https://www.amazon.com/dp/B0176M3U10    4.7   296710  11.99
# 28641  https://www.amazon.com/dp/B00JO8PEN2    4.7   289251  11.99
# 28634  https://www.amazon.com/dp/B0976V6YSL    4.7   242575   5.99
# 28654  https://www.amazon.com/dp/B085BVSXS9    4.3   234933  13.99
#
#        isBestSeller  isEditorsPick  isGoodReadsChoice         category_name
# 28874         False           True              False  Literature & Fiction
# 28628         False          False               True  Literature & Fiction
# 28641         False           True              False  Literature & Fiction
# 28634         False           True              False  Literature & Fiction
# 28654         False           True              False  Literature & Fiction

# %%
# top 5 stars
top_5_stars = top(df, 'stars', 5)
top_5_stars
# Out:
#                                                    title  \
# 6926         Engineering Mechanics: Statics and Dynamics
# 46385  The cicada and the bird: The usefulness of a u...
# 46310  Restorative Justice: Integrating Theory, Resea...
# 27560  The Dictionary of the Book: A Glossary for Boo...
# 10150  X-Ray Fluorescence Spectrometry and Related Te...
#
#                      author                   soldBy  \
# 6926         Michael Plesha  Amazon.com Services LLC
# 46385   Christopher Tricker  Amazon.com Services LLC
# 46310  Aida Y. Hass-Wisecup  Amazon.com Services LLC
# 27560      Sidney E. Berger  Amazon.com Services LLC
# 10150            Eva Margui  Amazon.com Services LLC
#
#                                                   imgUrl  \
# 6926   https://m.media-amazon.com/images/I/71bDathFoI...
# 46385  https://m.media-amazon.com/images/I/71w-UYIA+R...
# 46310  https://m.media-amazon.com/images/I/71zgV9WOX6...
# 27560  https://m.media-amazon.com/images/I/81bQlgQoEN...
# 10150  https://m.media-amazon.com/images/I/710c4rmQyZ...
#
#                                  productURL  stars  reviews   price  \
# 6926   https://www.amazon.com/dp/B09S19617T    5.0        0   65.00
# 46385  https://www.amazon.com/dp/B0BLMBS771    5.0        3    9.99
# 46310  https://www.amazon.com/dp/B09PFHS5XF    5.0        2   48.00
# 27560  https://www.amazon.com/dp/B0BML4JS46    5.0        0  105.19
# 10150  https://www.amazon.com/dp/B0149MCA9S    5.0        0  147.93
#
#        isBestSeller  isEditorsPick  isGoodReadsChoice  \
# 6926          False          False              False
# 46385         False          False              False
# 46310         False          False              False
# 27560         False          False              False
# 10150         False          False              False
#
#                       category_name
# 6926   Engineering & Transportation
# 46385    Politics & Social Sciences
# 46310    Politics & Social Sciences
# 27560        Crafts, Hobbies & Home
# 10150  Engineering & Transportation

# %%
df.author.value_counts().head() # authors with the highest num of books
# Out:
# author
# DK Eyewitness            159
# James Patterson          150
# DK                       131
# Captivating History      118
# Fodor's Travel Guides    115
# Name: count, dtype: int64

# %%
df.category_name.value_counts().head(10) # category with the highest num of books
# Out:
# category_name
# Mystery, Thriller & Suspense    6224
# Engineering & Transportation    6053
# Science & Math                  5882
# Parenting & Relationships       5702
# Teen & Young Adult              5613
# LGBTQ+ eBooks                   5468
# Computers & Technology          5442
# Crafts, Hobbies & Home          5427
# Biographies & Memoirs           5355
# Travel                          5317
# Name: count, dtype: int64

# %%
df.reviews.value_counts()
# Out:
# reviews
# 0        57894
# 1          659
# 2          499
# 3          442
# 4          411
#          ...
# 6161         1
# 9109         1
# 9073         1
# 4538         1
# 13498        1
# Name: count, Length: 8045, dtype: int64

# %%
df[df['reviews'] >= 50].shape # Shape of the dataset with reviews greater than 50
# Out:
# (53306, 12)

# %%
final_df = df[df['reviews'] >= 50]

# %%
final_df.head(2)
# Out:
#                                            title            author  \
# 28600  The Covenant of Water (Oprah's Book Club)  Abraham Verghese
# 28601         Tom Lake: A Reese's Book Club Pick      Ann Patchett
#
#                          soldBy  \
# 28600   Amazon.com Services LLC
# 28601  HarperCollins Publishers
#
#                                                   imgUrl  \
# 28600  https://m.media-amazon.com/images/I/91b7tm523V...
# 28601  https://m.media-amazon.com/images/I/91XPKk96LX...
#
#                                  productURL  stars  reviews  price  \
# 28600  https://www.amazon.com/dp/B0BJSGV831    4.7    31767   9.24
# 28601  https://www.amazon.com/dp/B0BL126WSH    4.4    10325  15.99
#
#        isBestSeller  isEditorsPick  isGoodReadsChoice         category_name
# 28600         False           True              False  Literature & Fiction
# 28601         False           True              False  Literature & Fiction

# %%
duplicate_rows = final_df[final_df.duplicated()]

# Get the number of duplicate rows
num_duplicates = len(duplicate_rows)
num_duplicates
# Out:
# 0

# %%
final_df.drop_duplicates(['title'], inplace=True)
# Out:
# C:\Users\Ojo Ridwan\AppData\Local\Temp\ipykernel_12736\3498879094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop_duplicates(['title'], inplace=True)

# %%
final_df.shape # Check for the new shape of the dataset
# Out:
# (53200, 12)

# %%
final_df.reset_index(inplace=True) # Reset the index

# %%
final_df.drop(columns='index', inplace=True)
# Out:
# C:\Users\Ojo Ridwan\AppData\Local\Temp\ipykernel_12736\4027325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns='index', inplace=True)

# %%
final_df.head(2)
# Out:
#                                        title            author  \
# 0  The Covenant of Water (Oprah's Book Club)  Abraham Verghese
# 1         Tom Lake: A Reese's Book Club Pick      Ann Patchett
#
#                      soldBy  \
# 0   Amazon.com Services LLC
# 1  HarperCollins Publishers
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/91b7tm523V...
# 1  https://m.media-amazon.com/images/I/91XPKk96LX...
#
#                              productURL  stars  reviews  price  isBestSeller  \
# 0  https://www.amazon.com/dp/B0BJSGV831    4.7    31767   9.24         False
# 1  https://www.amazon.com/dp/B0BL126WSH    4.4    10325  15.99         False
#
#    isEditorsPick  isGoodReadsChoice         category_name
# 0           True              False  Literature & Fiction
# 1           True              False  Literature & Fiction

# %%
final_df.author.nunique()
# Out:
# 28476

# %%
book_pivot = final_df.pivot_table(columns='author', index='title', values='reviews')

# %%
import pandas as pd

# Assuming you have a DataFrame named final_df
# You can create a subset of data before pivoting
subset_df = final_df.sample(n=1000)  # Adjust the number based on your available memory

# Perform the pivot operation on the subset
book_pivot = subset_df.pivot_table(columns='author', index='title', values='reviews')

# %%
book_pivot
# Out:
# author                                              A. G. Howard  \
# title
# 1%. The book that the financial establishment d...           NaN
# 100 Days of Right Believing: Daily Readings fro...           NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...           NaN
# 1000 Years of Joys and Sorrows: A Memoir                     NaN
# 101 Essential Life Skills For Teens: How to Bec...           NaN
# ...                                                          ...
# Zion: The Complete Guide: Zion National Park (C...           NaN
# Zwischen Welten: Roman (German Edition)                      NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...           NaN
# Доктор Живаго (Russian Edition)                              NaN
# Тревожные люди (Russian Edition)                             NaN
#
# author                                              A.J. Messenger  \
# title
# 1%. The book that the financial establishment d...             NaN
# 100 Days of Right Believing: Daily Readings fro...             NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...             NaN
# 1000 Years of Joys and Sorrows: A Memoir                       NaN
# 101 Essential Life Skills For Teens: How to Bec...             NaN
# ...                                                            ...
# Zion: The Complete Guide: Zion National Park (C...             NaN
# Zwischen Welten: Roman (German Edition)                        NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...             NaN
# Доктор Живаго (Russian Edition)                                NaN
# Тревожные люди (Russian Edition)                               NaN
#
# author                                              A.T. Butler  \
# title
# 1%. The book that the financial establishment d...          NaN
# 100 Days of Right Believing: Daily Readings fro...          NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...          NaN
# 1000 Years of Joys and Sorrows: A Memoir                    NaN
# 101 Essential Life Skills For Teens: How to Bec...          NaN
# ...                                                         ...
# Zion: The Complete Guide: Zion National Park (C...          NaN
# Zwischen Welten: Roman (German Edition)                     NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...          NaN
# Доктор Живаго (Russian Edition)                             NaN
# Тревожные люди (Russian Edition)                            NaN
#
# author                                              Aaron Dembski-Bowden  \
# title
# 1%. The book that the financial establishment d...                   NaN
# 100 Days of Right Believing: Daily Readings fro...                   NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...                   NaN
# 1000 Years of Joys and Sorrows: A Memoir                             NaN
# 101 Essential Life Skills For Teens: How to Bec...                   NaN
# ...                                                                  ...
# Zion: The Complete Guide: Zion National Park (C...                   NaN
# Zwischen Welten: Roman (German Edition)                              NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...                   NaN
# Доктор Живаго (Russian Edition)                                      NaN
# Тревожные люди (Russian Edition)                                     NaN
#
# author                                              Abbi Glines  \
# title
# 1%. The book that the financial establishment d...          NaN
# 100 Days of Right Believing: Daily Readings fro...          NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...          NaN
# 1000 Years of Joys and Sorrows: A Memoir                    NaN
# 101 Essential Life Skills For Teens: How to Bec...          NaN
# ...                                                         ...
# Zion: The Complete Guide: Zion National Park (C...          NaN
# Zwischen Welten: Roman (German Edition)                     NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...          NaN
# Доктор Живаго (Russian Edition)                             NaN
# Тревожные люди (Russian Edition)                            NaN
#
# author                                              Abdulrazak Gurnah  \
# title
# 1%. The book that the financial establishment d...                NaN
# 100 Days of Right Believing: Daily Readings fro...                NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...                NaN
# 1000 Years of Joys and Sorrows: A Memoir                          NaN
# 101 Essential Life Skills For Teens: How to Bec...                NaN
# ...                                                               ...
# Zion: The Complete Guide: Zion National Park (C...                NaN
# Zwischen Welten: Roman (German Edition)                           NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...                NaN
# Доктор Живаго (Russian Edition)                                   NaN
# Тревожные люди (Russian Edition)                                  NaN
#
# author                                              Abigail Drake  \
# title
# 1%. The book that the financial establishment d...            NaN
# 100 Days of Right Believing: Daily Readings fro...            NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...            NaN
# 1000 Years of Joys and Sorrows: A Memoir                      NaN
# 101 Essential Life Skills For Teens: How to Bec...            NaN
# ...                                                           ...
# Zion: The Complete Guide: Zion National Park (C...            NaN
# Zwischen Welten: Roman (German Edition)                       NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...            NaN
# Доктор Живаго (Russian Edition)                               NaN
# Тревожные люди (Russian Edition)                              NaN
#
# author                                              Abigail Taylor  \
# title
# 1%. The book that the financial establishment d...             NaN
# 100 Days of Right Believing: Daily Readings fro...             NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...             NaN
# 1000 Years of Joys and Sorrows: A Memoir                       NaN
# 101 Essential Life Skills For Teens: How to Bec...             NaN
# ...                                                            ...
# Zion: The Complete Guide: Zion National Park (C...             NaN
# Zwischen Welten: Roman (German Edition)                        NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...             NaN
# Доктор Живаго (Russian Edition)                                NaN
# Тревожные люди (Russian Edition)                               NaN
#
# author                                              Abiola Abrams  \
# title
# 1%. The book that the financial establishment d...            NaN
# 100 Days of Right Believing: Daily Readings fro...            NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...            NaN
# 1000 Years of Joys and Sorrows: A Memoir                      NaN
# 101 Essential Life Skills For Teens: How to Bec...            NaN
# ...                                                           ...
# Zion: The Complete Guide: Zion National Park (C...            NaN
# Zwischen Welten: Roman (German Edition)                       NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...            NaN
# Доктор Живаго (Russian Edition)                               NaN
# Тревожные люди (Russian Edition)                              NaN
#
# author                                              Adam Hamilton  ...  \
# title                                                              ...
# 1%. The book that the financial establishment d...            NaN  ...
# 100 Days of Right Believing: Daily Readings fro...            NaN  ...
# 100 Most Beautiful Songs Ever for Fingerstyle U...            NaN  ...
# 1000 Years of Joys and Sorrows: A Memoir                      NaN  ...
# 101 Essential Life Skills For Teens: How to Bec...            NaN  ...
# ...                                                           ...  ...
# Zion: The Complete Guide: Zion National Park (C...            NaN  ...
# Zwischen Welten: Roman (German Edition)                       NaN  ...
# ggplot2: Elegant Graphics for Data Analysis (Us...            NaN  ...
# Доктор Живаго (Russian Edition)                               NaN  ...
# Тревожные люди (Russian Edition)                              NaN  ...
#
# author                                              Yan Pritzker  \
# title
# 1%. The book that the financial establishment d...           NaN
# 100 Days of Right Believing: Daily Readings fro...           NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...           NaN
# 1000 Years of Joys and Sorrows: A Memoir                     NaN
# 101 Essential Life Skills For Teens: How to Bec...           NaN
# ...                                                          ...
# Zion: The Complete Guide: Zion National Park (C...           NaN
# Zwischen Welten: Roman (German Edition)                      NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...           NaN
# Доктор Живаго (Russian Edition)                              NaN
# Тревожные люди (Russian Edition)                             NaN
#
# author                                              Yangsze Choo  \
# title
# 1%. The book that the financial establishment d...           NaN
# 100 Days of Right Believing: Daily Readings fro...           NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...           NaN
# 1000 Years of Joys and Sorrows: A Memoir                     NaN
# 101 Essential Life Skills For Teens: How to Bec...           NaN
# ...                                                          ...
# Zion: The Complete Guide: Zion National Park (C...           NaN
# Zwischen Welten: Roman (German Edition)                      NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...           NaN
# Доктор Живаго (Russian Edition)                              NaN
# Тревожные люди (Russian Edition)                             NaN
#
# author                                              Yeshe Losal Rinpoche  \
# title
# 1%. The book that the financial establishment d...                   NaN
# 100 Days of Right Believing: Daily Readings fro...                   NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...                   NaN
# 1000 Years of Joys and Sorrows: A Memoir                             NaN
# 101 Essential Life Skills For Teens: How to Bec...                   NaN
# ...                                                                  ...
# Zion: The Complete Guide: Zion National Park (C...                   NaN
# Zwischen Welten: Roman (German Edition)                              NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...                   NaN
# Доктор Живаго (Russian Edition)                                      NaN
# Тревожные люди (Russian Edition)                                     NaN
#
# author                                              Yomu Mishima  Zach Neese  \
# title
# 1%. The book that the financial establishment d...           NaN         NaN
# 100 Days of Right Believing: Daily Readings fro...           NaN         NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...           NaN         NaN
# 1000 Years of Joys and Sorrows: A Memoir                     NaN         NaN
# 101 Essential Life Skills For Teens: How to Bec...           NaN         NaN
# ...                                                          ...         ...
# Zion: The Complete Guide: Zion National Park (C...           NaN         NaN
# Zwischen Welten: Roman (German Edition)                      NaN         NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...           NaN         NaN
# Доктор Живаго (Russian Edition)                              NaN         NaN
# Тревожные люди (Russian Edition)                             NaN         NaN
#
# author                                              qntm  Борис Пастернак  \
# title
# 1%. The book that the financial establishment d...   NaN              NaN
# 100 Days of Right Believing: Daily Readings fro...   NaN              NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...   NaN              NaN
# 1000 Years of Joys and Sorrows: A Memoir             NaN              NaN
# 101 Essential Life Skills For Teens: How to Bec...   NaN              NaN
# ...                                                  ...              ...
# Zion: The Complete Guide: Zion National Park (C...   NaN              NaN
# Zwischen Welten: Roman (German Edition)              NaN              NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...   NaN              NaN
# Доктор Живаго (Russian Edition)                      NaN            475.0
# Тревожные люди (Russian Edition)                     NaN              NaN
#
# author                                              Фредрик Бакман  李娟  甘岸久弥
# title
# 1%. The book that the financial establishment d...             NaN NaN   NaN
# 100 Days of Right Believing: Daily Readings fro...             NaN NaN   NaN
# 100 Most Beautiful Songs Ever for Fingerstyle U...             NaN NaN   NaN
# 1000 Years of Joys and Sorrows: A Memoir                       NaN NaN   NaN
# 101 Essential Life Skills For Teens: How to Bec...             NaN NaN   NaN
# ...                                                            ...  ..   ...
# Zion: The Complete Guide: Zion National Park (C...             NaN NaN   NaN
# Zwischen Welten: Roman (German Edition)                        NaN NaN   NaN
# ggplot2: Elegant Graphics for Data Analysis (Us...             NaN NaN   NaN
# Доктор Живаго (Russian Edition)                                NaN NaN   NaN
# Тревожные люди (Russian Edition)                              74.0 NaN   NaN
#
# [1000 rows x 950 columns]

# %%
df.columns
# Out:
# Index(['title', 'author', 'soldBy', 'imgUrl', 'productURL', 'stars', 'reviews',
#        'price', 'isBestSeller', 'isEditorsPick', 'isGoodReadsChoice',
#        'category_name'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                                                title             author  \
# 0  Adult Children of Emotionally Immature Parents...  Lindsay C. Gibson
# 1  From Strength to Strength: Finding Success, Ha...   Arthur C. Brooks
# 2  Good Inside: A Guide to Becoming the Parent Yo...      Becky Kennedy
#
#                      soldBy  \
# 0   Amazon.com Services LLC
# 1   Penguin Group (USA) LLC
# 2  HarperCollins Publishers
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/713KZTsaYp...
# 1  https://m.media-amazon.com/images/I/A1LZcJFs9E...
# 2  https://m.media-amazon.com/images/I/71RIWM0sv6...
#
#                              productURL  stars  reviews  price  isBestSeller  \
# 0  https://www.amazon.com/dp/B00TZE87S4    4.8        0   9.99          True
# 1  https://www.amazon.com/dp/B08WCKY8MB    4.4        0  16.99         False
# 2  https://www.amazon.com/dp/B09KPS84CJ    4.8        0  16.99         False
#
#    isEditorsPick  isGoodReadsChoice              category_name
# 0          False              False  Parenting & Relationships
# 1          False              False  Parenting & Relationships
# 2           True              False  Parenting & Relationships

# %%
df.columns
# Out:
# Index(['title', 'author', 'soldBy', 'imgUrl', 'productURL', 'stars', 'reviews',
#        'price', 'isBestSeller', 'isEditorsPick', 'isGoodReadsChoice',
#        'category_name'],
#       dtype='object')
